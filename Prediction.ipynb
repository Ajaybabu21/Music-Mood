# %%
import numpy as np
import os
import pandas as pd
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import seaborn as sns

# %%
path='data_moods.csv'
#data=pd.read_csv('data_moods.csv')
data = pd.read_csv('data_moods.csv', encoding='unicode_escape')
features = data[['danceability','liveness','acousticness','loudness','speechiness','valence','energy']]
from sklearn.cluster import KMeans

sse = {}
K = range(1,12)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(features)
    sse[k]=km.inertia_
    kmeans = KMeans(n_clusters=4)
kmeans.fit(features)
labels=kmeans.labels_
rfm=data.assign(Cluster=labels)
group=rfm.groupby(["Cluster"])
group.agg({
    
    'danceability':'mean',
    'loudness':'mean',
     'valence':'mean',
    'acousticness':['mean','count'],
   

}).round(1)
rfm[rfm['Cluster']==1]
rfm[rfm['Cluster']==2]
rfm[rfm['Cluster']==3]
rfm[rfm['Cluster']==0]
# Out:
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#                                                   name  \
# 0                                          I am Sachin
# 3                                       99 Luftballons
# 7    A Little Less Conversation - JXL Radio Edit Remix
# 11                                         Adjustments
# 18                                              Alison
# ..                                                 ...
# 673  i don't want to watch the world end with someo...
# 674                               lovely (with Khalid)
# 676                                no song without you
# 680                              when the party's over
# 683                                 you broke me first
#
#                                                  album         artist  \
# 0                                                 1999         Prince
# 3                                       99 Luftballons           Nena
# 7                      Elvis 75 - Good Rockin' Tonight  Elvis Presley
# 11                                         Adjustments   Josie Mehlin
# 18                                            Souvlaki       Slowdive
# ..                                                 ...            ...
# 673  i don't want to watch the world end with someo...   Clinton Kane
# 674                               lovely (with Khalid)  Billie Eilish
# 676                                no song without you          HONNE
# 680           WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?  Billie Eilish
# 683                                 you broke me first     Tate McRae
#
#                          id release_date  popularity  length  danceability  \
# 0    2H7PHVdQ3mXqEHXcvclTB0   27-10-1982          68  379266         0.866
# 3    6HA97v4wEGQ5TUClRM0XLc   21-08-1984           2  233000         0.466
# 7    4l2hnfUx0esSbITQa7iJt0   28-12-2009           1  211173         0.586
# 11   6w0vhPaZBYjhrDobs3QE14   17-01-2020          52  182000         0.532
# 18   55CenVQ4alvDJ1PS8aYB0m         1993           0  231893         0.279
# ..                      ...          ...         ...     ...           ...
# 673  58qX77t2VWMWcycsh9zKLc   08-05-2020          68  184505         0.535
# 674  0u2P5u6lvoDfwTYjAADbn4   19-04-2018          88  200185         0.351
# 676  3KKUf8F2hktFscLgbH4YwR   12-06-2020          75  161536         0.778
# 680  43zdsphuZLzwA9k4DJhU0I   29-03-2019          87  196077         0.367
# 683  45bE4HXI0AwGZXfZtMp8JR   17-04-2020          87  169265         0.642
#
#      acousticness  energy  instrumentalness  liveness  valence  loudness  \
# 0        0.137000   0.730          0.000000    0.0843   0.6250    -8.201
# 3        0.089000   0.438          0.000006    0.1130   0.5870   -12.858
# 7        0.000155   0.935          0.277000    0.1590   0.5800    -9.386
# 11       0.974000   0.541          0.864000    0.2280   0.3290   -11.932
# 18       0.009570   0.423          0.837000    0.1280   0.2910   -12.060
# ..            ...     ...               ...       ...      ...       ...
# 673      0.771000   0.359          0.000000    0.1110   0.4880    -9.343
# 674      0.934000   0.296          0.000000    0.0950   0.1200   -10.109
# 676      0.463000   0.462          0.583000    0.1100   0.8170   -12.729
# 680      0.978000   0.111          0.000040    0.0897   0.1980   -14.084
# 683      0.786000   0.374          0.000000    0.0906   0.0799    -9.386
#
#      speechiness    tempo  key  time_signature   mood  Cluster
# 0         0.0767  118.523    5               4  Happy        0
# 3         0.0608  193.100    4               4  Happy        0
# 7         0.0482  114.997    4               4  Happy        0
# 11        0.0283  136.063    0               4   Calm        0
# 18        0.0380  101.571    4               4    Sad        0
# ..           ...      ...  ...             ...    ...      ...
# 673       0.0607  154.163    2               4    Sad        0
# 674       0.0333  115.284    4               4    Sad        0
# 676       0.0359  105.450    0               4    Sad        0
# 680       0.0972   82.642    4               4    Sad        0
# 683       0.0545  124.099    4               4    Sad        0
#
# [215 rows x 20 columns]
