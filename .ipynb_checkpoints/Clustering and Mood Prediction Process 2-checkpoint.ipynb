# %% [markdown]
# # CLUSTERING AND MOOD PREDICTION

# %%
import numpy as np
import os
import pandas as pd
# To make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import seaborn as sns
#set style of plots
sns.set_style('white')
#define a custom palette
customPalette = ['#630C3A', '#39C8C6', '#D3500C', '#FFB139']
sns.set_palette(customPalette)
sns.palplot(customPalette)
# Ignore useless warnings (see SciPy issue #5998)
# Out:
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
path='data_moods.csv'

# %%
data=pd.read_csv('data_moods.csv')

# %%
s=data.groupby("artist")["popularity"].sum().sort_values(ascending=False).head(170652)

# %%
s.head(10)
# Out:
# artist
# Various Artists        305
# Prince                 265
# Billie Eilish          257
# Linkin Park            240
# My Chemical Romance    238
# Wilson Trouvé          183
# Lewis Capaldi          169
# Blasterjaxx            167
# The Beatles            157
# Monocle Twins          156
# Name: popularity, dtype: int64

# %% [markdown]
# # DATA PREPROCESSING

# %%
features = data[['danceability','liveness','acousticness','loudness','speechiness','valence','energy']]

# %%
from sklearn import preprocessing

loudness = features[['loudness']].values
min_max_scaler = preprocessing.MinMaxScaler()
loudness_scaled = min_max_scaler.fit_transform(loudness)
data['loudness'] = pd.DataFrame(loudness_scaled)




features.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'danceability'}>,
#         <AxesSubplot:title={'center':'liveness'}>,
#         <AxesSubplot:title={'center':'acousticness'}>],
#        [<AxesSubplot:title={'center':'loudness'}>,
#         <AxesSubplot:title={'center':'speechiness'}>,
#         <AxesSubplot:title={'center':'valence'}>],
#        [<AxesSubplot:title={'center':'energy'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
from sklearn.cluster import KMeans

sse = {}
K = range(1,12)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(features)
    sse[k]=km.inertia_
# Out:
# C:\Users\SACHIN giyo SUNNY\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %% [markdown]
# # K NEAREST NEIGHBOR ALGORITHM

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(features)
labels=kmeans.labels_

# %%
rfm=data.assign(Cluster=labels)
group=rfm.groupby(["Cluster"])
group.agg({
    
    'danceability':'mean',
    'loudness':'mean',
     'valence':'mean',
    'acousticness':['mean','count'],
   

}).round(1)
# Out:
#         danceability loudness valence acousticness
#                 mean     mean    mean         mean count
# Cluster
# 0                0.4      0.4     0.2          1.0   111
# 1                0.5      0.6     0.3          0.7   189
# 2                0.5      0.8     0.4          0.2   386

# %%
rfm_melt=pd.melt(rfm.reset_index(), id_vars =['artist','Cluster'],value_vars=['danceability','loudness','acousticness','valence'],var_name='Metric',value_name='Value')

# %%
plt.xlabel('Metric')
plt.ylabel('Value')
plt.title('snake plot')
sns.pointplot(data=rfm_melt,x='Metric',y='Value',hue='Cluster')
# Out:
# <AxesSubplot:title={'center':'snake plot'}, xlabel='Metric', ylabel='Value'>

# %%
rfm[rfm['Cluster']==1]
# Out:
#                      name             album              artist  \
# 5        A Burden to Bear  A Burden to Bear  Emmanuelle Rimbaud
# 6              A La Plage        A La Plage         Ron Adelaar
# 15         After The Rain    After The Rain          Comet Blue
# 27                  Ambre       Wintermusik          Nils Frahm
# 28               Anaviosi          Anaviosi     Alexi Musnitsky
# ..                    ...               ...                 ...
# 660  You Are Safe With Me       delta/alpha         Jef Martens
# 670            coeur noir        coeur noir           Leo Nocta
# 679        the theme song            notion      Teodor Wolgers
# 681           windcatcher       windcatcher           Leo Nocta
# 685                  æfre              æfre               praam
#
#                          id release_date  popularity  length  danceability  \
# 5    67DOFCrkcQaLp5yhzF8Y8N   2020-07-31          27  129410         0.394
# 6    79NmiFAgcXUIVDGfCWDdWF   2020-08-07          29  141888         0.504
# 15   2XBc2jWnvPqNO2LebVtLaY   2020-08-03          24  116625         0.456
# 27   0suQ6B8Bsp0tFuCXx652Az   2009-12-04           0  227639         0.391
# 28   4OWZLr2sLv7ueKPHV7JRNP   2020-07-09          38  174244         0.391
# ..                      ...          ...         ...     ...           ...
# 660  4t2XUVB63KvQWeAlAaaqAz   2020-05-01          35   86125         0.392
# 670  0JsYp2UosjQpePYbHCvXWZ   2020-07-17          34  262280         0.235
# 679  3n2QaRyg5nTg5Cwwq5mw3Q   2020-04-24          36  159840         0.604
# 681  59VApBbrS2IADQk4ml5mdo   2020-06-19          36  123066         0.402
# 685  2irbT1BSYaIEF44PlyKaoM   2020-07-17          41  186331         0.377
#
#      acousticness  energy  instrumentalness  liveness  valence  loudness  \
# 5           0.995  0.0475             0.955    0.1050   0.1720  0.359456
# 6           0.994  0.0584             0.956    0.1150   0.5530  0.497163
# 15          0.993  0.0337             0.948    0.1260   0.3000  0.349354
# 27          0.992  0.0576             0.947    0.1170   0.3590  0.378990
# 28          0.995  0.0121             0.946    0.0959   0.1180  0.401983
# ..            ...     ...               ...       ...      ...       ...
# 660         0.990  0.0390             0.949    0.1000   0.3890  0.331527
# 670         0.926  0.2330             0.890    0.0690   0.1640  0.480743
# 679         0.986  0.0300             0.952    0.1050   0.1500  0.346195
# 681         0.961  0.2360             0.919    0.0921   0.1460  0.493612
# 685         0.994  0.0156             0.881    0.0991   0.0804  0.313261
#
#      speechiness    tempo  key  time_signature  mood  Cluster
# 5         0.0720   71.241    6               5  Calm        1
# 6         0.0516  134.209    5               4  Calm        1
# 15        0.0334   97.199    0               4  Calm        1
# 27        0.0342  145.569   10               3  Calm        1
# 28        0.0852   68.128    1               4  Calm        1
# ..           ...      ...  ...             ...   ...      ...
# 660       0.0312   99.731    9               4  Calm        1
# 670       0.0712   66.866   11               3  Calm        1
# 679       0.0386  117.781    0               4  Calm        1
# 681       0.0603  129.736    0               3  Calm        1
# 685       0.0397  140.179    0               4  Calm        1
#
# [111 rows x 20 columns]

# %%
rfm[rfm['Cluster']==2]
# Out:
#                      name             album              artist  \
# 5        A Burden to Bear  A Burden to Bear  Emmanuelle Rimbaud
# 6              A La Plage        A La Plage         Ron Adelaar
# 15         After The Rain    After The Rain          Comet Blue
# 27                  Ambre       Wintermusik          Nils Frahm
# 28               Anaviosi          Anaviosi     Alexi Musnitsky
# ..                    ...               ...                 ...
# 660  You Are Safe With Me       delta/alpha         Jef Martens
# 670            coeur noir        coeur noir           Leo Nocta
# 679        the theme song            notion      Teodor Wolgers
# 681           windcatcher       windcatcher           Leo Nocta
# 685                  æfre              æfre               praam
#
#                          id release_date  popularity  length  danceability  \
# 5    67DOFCrkcQaLp5yhzF8Y8N   2020-07-31          27  129410         0.394
# 6    79NmiFAgcXUIVDGfCWDdWF   2020-08-07          29  141888         0.504
# 15   2XBc2jWnvPqNO2LebVtLaY   2020-08-03          24  116625         0.456
# 27   0suQ6B8Bsp0tFuCXx652Az   2009-12-04           0  227639         0.391
# 28   4OWZLr2sLv7ueKPHV7JRNP   2020-07-09          38  174244         0.391
# ..                      ...          ...         ...     ...           ...
# 660  4t2XUVB63KvQWeAlAaaqAz   2020-05-01          35   86125         0.392
# 670  0JsYp2UosjQpePYbHCvXWZ   2020-07-17          34  262280         0.235
# 679  3n2QaRyg5nTg5Cwwq5mw3Q   2020-04-24          36  159840         0.604
# 681  59VApBbrS2IADQk4ml5mdo   2020-06-19          36  123066         0.402
# 685  2irbT1BSYaIEF44PlyKaoM   2020-07-17          41  186331         0.377
#
#      acousticness  energy  instrumentalness  liveness  valence  loudness  \
# 5           0.995  0.0475             0.955    0.1050   0.1720  0.359456
# 6           0.994  0.0584             0.956    0.1150   0.5530  0.497163
# 15          0.993  0.0337             0.948    0.1260   0.3000  0.349354
# 27          0.992  0.0576             0.947    0.1170   0.3590  0.378990
# 28          0.995  0.0121             0.946    0.0959   0.1180  0.401983
# ..            ...     ...               ...       ...      ...       ...
# 660         0.990  0.0390             0.949    0.1000   0.3890  0.331527
# 670         0.926  0.2330             0.890    0.0690   0.1640  0.480743
# 679         0.986  0.0300             0.952    0.1050   0.1500  0.346195
# 681         0.961  0.2360             0.919    0.0921   0.1460  0.493612
# 685         0.994  0.0156             0.881    0.0991   0.0804  0.313261
#
#      speechiness    tempo  key  time_signature  mood  Cluster
# 5         0.0720   71.241    6               5  Calm        2
# 6         0.0516  134.209    5               4  Calm        2
# 15        0.0334   97.199    0               4  Calm        2
# 27        0.0342  145.569   10               3  Calm        2
# 28        0.0852   68.128    1               4  Calm        2
# ..           ...      ...  ...             ...   ...      ...
# 660       0.0312   99.731    9               4  Calm        2
# 670       0.0712   66.866   11               3  Calm        2
# 679       0.0386  117.781    0               4  Calm        2
# 681       0.0603  129.736    0               3  Calm        2
# 685       0.0397  140.179    0               4  Calm        2
#
# [106 rows x 20 columns]

# %%
rfm[rfm['Cluster']==0]
# Out:
#                                                   name  \
# 0                                                 1999
# 1                                                   23
# 4          A Boy Brushed Red Living In Black And White
# 7    A Little Less Conversation - JXL Radio Edit Remix
# 8                                  A Place for My Head
# ..                                                 ...
# 673  i don't want to watch the world end with someo...
# 674                               lovely (with Khalid)
# 677                                        pass you by
# 682                    yellow is the color of her eyes
# 683                                 you broke me first
#
#                                                  album           artist  \
# 0                                                 1999           Prince
# 1                                                   23   Blonde Redhead
# 4                          They're Only Chasing Safety        Underoath
# 7                      Elvis 75 - Good Rockin' Tonight    Elvis Presley
# 8                        Hybrid Theory (Bonus Edition)      Linkin Park
# ..                                                 ...              ...
# 673  i don't want to watch the world end with someo...     Clinton Kane
# 674                               lovely (with Khalid)    Billie Eilish
# 677                                     the voicenotes  Alaina Castillo
# 682                    yellow is the color of her eyes     Soccer Mommy
# 683                                 you broke me first       Tate McRae
#
#                          id release_date  popularity  length  danceability  \
# 0    2H7PHVdQ3mXqEHXcvclTB0   1982-10-27          68  379266         0.866
# 1    4HIwL9ii9CcXpTOTzMq0MP   2007-04-16          43  318800         0.381
# 4    47IWLfIKOKhFnz1FUEUIkE   2004-01-01          60  268000         0.419
# 7    4l2hnfUx0esSbITQa7iJt0   2009-12-28           1  211173         0.586
# 8    5rAxhWcgFng3s570sGO2F8   2000-10-24          68  184640         0.603
# ..                      ...          ...         ...     ...           ...
# 673  58qX77t2VWMWcycsh9zKLc   2020-05-08          68  184505         0.535
# 674  0u2P5u6lvoDfwTYjAADbn4   2018-04-19          88  200185         0.351
# 677  4NVwMupCTfITPXetR5aozp   2020-04-24          60  245945         0.510
# 682  4D3nttJPU6L0M2epr7sId6   2019-11-19           5  435080         0.452
# 683  45bE4HXI0AwGZXfZtMp8JR   2020-04-17          87  169265         0.642
#
#      acousticness  energy  instrumentalness  liveness  valence  loudness  \
# 0        0.137000   0.730             0.000    0.0843   0.6250  0.779912
# 1        0.018900   0.832             0.196    0.1530   0.1660  0.852145
# 4        0.001710   0.932             0.000    0.1370   0.4450  0.885932
# 7        0.000155   0.935             0.277    0.1590   0.5800  0.752583
# 8        0.014400   0.908             0.000    0.6710   0.4570  0.847878
# ..            ...     ...               ...       ...      ...       ...
# 673      0.771000   0.359             0.000    0.1110   0.4880  0.753575
# 674      0.934000   0.296             0.000    0.0950   0.1200  0.735909
# 677      0.892000   0.355             0.000    0.1330   0.4530  0.810309
# 682      0.757000   0.515             0.120    0.1400   0.1910  0.799516
# 683      0.786000   0.374             0.000    0.0906   0.0799  0.752583
#
#      speechiness    tempo  key  time_signature       mood  Cluster
# 0         0.0767  118.523    5               4      Happy        0
# 1         0.0492  120.255    8               4        Sad        0
# 4         0.1060  169.881    1               4  Energetic        0
# 7         0.0482  114.997    4               4      Happy        0
# 8         0.1840  133.063   11               4  Energetic        0
# ..           ...      ...  ...             ...        ...      ...
# 673       0.0607  154.163    2               4        Sad        0
# 674       0.0333  115.284    4               4        Sad        0
# 677       0.0287  141.796   11               4        Sad        0
# 682       0.0255   80.537   11               4        Sad        0
# 683       0.0545  124.099    4               4        Sad        0
#
# [386 rows x 20 columns]
